# %%
import pandas as pd
FinalData = pd.read_csv('assets/FinalData.csv')
FinalData
# Out:
#             PID  GrLivArea  SalePrice  LotFrontage  LotArea  LotShape  \
# 0     909176150        856     126000    81.468023     7890         4
# 1     905476230       1049     139500    42.000000     4235         4
# 2     911128020       1001     124900    60.000000     6060         4
# 3     535377150       1039     114000    80.000000     8146         4
# 4     534177230       1665     227000    70.000000     8400         4
# ...         ...        ...        ...          ...      ...       ...
# 2574  903205040        952     121000    66.633846     8854         4
# 2575  905402060       1733     139600    56.456790    13680         3
# 2576  909275030       2002     145000    82.000000     6270         4
# 2577  907192040       1842     217500    66.633846     8826         4
# 2578  906223180       1911     215000    80.000000     9554         3
#
#       OverallQual  OverallCond  MasVnrArea  ExterQual  ...  Season__Spring  \
# 0               6            6         0.0          3  ...               1
# 1               5            5       149.0          4  ...               0
# 2               5            9         0.0          4  ...               0
# 3               4            8         0.0          4  ...               1
# 4               8            6         0.0          4  ...               0
# ...           ...          ...         ...        ...  ...             ...
# 2574            6            6         0.0          3  ...               1
# 2575            3            5         0.0          3  ...               0
# 2576            5            6         0.0          3  ...               0
# 2577            7            5       144.0          4  ...               0
# 2578            8            5       125.0          4  ...               0
#
#       Season__Winter  SaleCondition__Other  NeighborhoodSafety__1  \
# 0                  0                     0                      0
# 1                  1                     0                      0
# 2                  0                     0                      1
# 3                  0                     0                      0
# 4                  0                     0                      0
# ...              ...                   ...                    ...
# 2574               0                     0                      1
# 2575               0                     0                      0
# 2576               0                     0                      1
# 2577               0                     0                      0
# 2578               0                     0                      0
#
#       NeighborhoodSafety__2  NeighborhoodSafety__3  NeighborhoodSafety__4  \
# 0                         0                      0                      0
# 1                         1                      0                      0
# 2                         0                      0                      0
# 3                         0                      1                      0
# 4                         1                      0                      0
# ...                     ...                    ...                    ...
# 2574                      0                      0                      0
# 2575                      1                      0                      0
# 2576                      0                      0                      0
# 2577                      1                      0                      0
# 2578                      0                      0                      0
#
#       NeighborhoodSafety__5  NeighborhoodSafety__7  NeighborhoodSD__5
# 0                         1                      0                  0
# 1                         0                      0                  0
# 2                         0                      0                  0
# 3                         0                      0                  0
# 4                         0                      0                  0
# ...                     ...                    ...                ...
# 2574                      0                      0                  0
# 2575                      0                      0                  0
# 2576                      0                      0                  0
# 2577                      0                      0                  0
# 2578                      1                      0                  0
#
# [2579 rows x 105 columns]

# %%
len(FinalData.columns)
# Out:
# 105

# %%
import numpy as np
import os
import pickle
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet



#Multi-Linear Model
x = FinalData.drop(['SalePrice'],axis=1)

x['GrLivArea']=np.log(x['GrLivArea'])
x['LotArea']=np.log(x['LotArea'])
x['LotFrontage']=np.log(x['LotFrontage'])
x['MasVnrArea']=np.log(x['MasVnrArea']+0.0000001)
x['Totalbathr']=np.log(x['Totalbathr'])
x['Outside_Spaces']=np.log(x['Outside_Spaces']+0.000001)
x['TotRmsAbvGrd']=np.log(x['TotRmsAbvGrd'])

y = FinalData['SalePrice']
y=np.log(y)

#to convert whatever strings your data might contain to numeric values. 
#If they're incompatible with conversion, they'll be reduced to NaNs.
x = x.apply(pd.to_numeric, errors='coerce')
y = y.apply(pd.to_numeric, errors='coerce')
x.fillna(0, inplace=True)
y.fillna(0, inplace=True)


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 41)
elasticnet = ElasticNet(alpha=0.000041775510204081, l1_ratio=0.9591836734693877, normalize=True)
elasticnet.fit(x_train, y_train)
print(r'The R^2 is %.5f' %(elasticnet.score(x_train, y_train)))
print(r'The R^2 is %.5f' %(elasticnet.score(x_test, y_test)))
elasticnet.coef_,  elasticnet.intercept_

elasticnet.score(x_test, y_test)
# Out:
# The R^2 is 0.92104
# The R^2 is 0.94137
# /Users/layalhammad/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), ElasticNet())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to original_alpha * np.sqrt(n_samples) if l1_ratio is 1, and to original_alpha * n_samples if l1_ratio is 0. For other values of l1_ratio, no analytic formula is available.
#   warnings.warn(
# 0.9413675024684308

# %%
len(elasticnet.feature_names_in_)
# Out:
# 104

# %%
pickle.dump(elasticnet, open('assets/model.pkl', 'wb'))

# %%
a = FinalData

# %%
a.to_csv('assets/pkl_base.csv', index=False)

# %%
len(FinalData.columns)
# Out:
# 105
